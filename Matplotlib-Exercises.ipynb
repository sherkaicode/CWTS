# %%
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt

sys.path.append('./.Scripts') 

from checker_4 import checker_ans

score = {}

for i in range(1, 21):
    score[f"{i}"] = 0

def check_score(score):
    total_sum = 0
    for i in range(1, 21):
        total_sum = total_sum + score[f"{i}"]
    return f"You Total Score is {total_sum}"

# %% [markdown]
# ### **Question 1**

# %%
num = 1

"""
True or False: plt.plot() can only be used for bar cha.?
"""

answer = False

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 2**

# %%
num = 2
"""
True or False: Matplotlib can only plot 2D graphs.
"""

answer = False

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 3**

# %%
num = 3
"""
True or False: Multiple lines can be plotted using a single plt.plot() call.
"""

answer = True

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 4**

# %%
num = 4

"""
What does the plt.plot() function do?

A. Plots scatter data
B. Draws a line chart
C. Displays a bar chart
D. Opens a new window, then plots the data

"""
answer = "b"

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 5**

# %%
num = 5

"""
What will plt.grid(True) do?

A. Show gridlines on the plot
B. Make the plot 3D
C. Export the plot with gridlines
D. Increase the range of axes to add gridlines

"""

answer = "a"

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 6**

# %%
num = 6
"""
What does the alpha parameter in plotting control?

A. Color brightness
B. Font color
C. Transparency
D. Line width

"""
answer = "c"

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 7**

# %%
num = 7
"""
What does plt.legend do?

A. Adds a caption
B. Adds legend to the plot
C. Sets legend to the axis
D. Plots data points

"""
answer = "b"

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 8**

# %%
num = 8
"""
Which method is used for saving a figure?

A. plt.save()
B. plt.download()
C. plt.savefig()
D. plt.install()

"""
answer = "c"

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 9**

# %%
num = 9
"""
Which function is used to plot histograms?

A. plt.histogram()
B. plt.hist()
C. plt.bins()
D. plt.chart()

"""
answer = "b"

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 10**

# %%
num = 10
"""
Which changes the thickness of the line of the plot?

A. linestyle
B. linewidth
C. bold
D. thickness

"""
answer = "b"

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 11**

# %%
num = 11
"""
Create a scatter plot with x = [1, 2, 3] and y = [4, 5, 6].
"""

def answer():
    "Answer here (return nothing just plot)"
    plt.scatter([1, 2, 3], [4, 5, 6])

    
checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 12**

# %%
num = 12
"""
Plot a simple sine wave (sin(x)) with the title “Sine wave”
"""

def answer():
    "Answer here (return nothing just plot). Do not plt.show()"
    x = np.linspace(0, 2 * np.pi, 100)
    y = np.sin(x)
    plt.plot(x, y)
    plt.title("Sine wave.")

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 13**

# %%
num = 13
"""
Plot a line, then change the color of the plot to red and increase its width to 3.
"""

def answer():
    "Answer here (return nothing just plot). Do not plt.show()"
    x = [1, 2, 3]
    y = [2, 3, 4]
    plt.plot(x, y, color = "red", linewidth = 3)
    

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 14**

# %%
num = 14
"""
Plot a bar chart for student scores: names = [Puffy, Jelly, Judy], scores = [91, 85, 79].
"""

def answer():
    "Answer here (return nothing just plot). Do not plt.show()"
    names = ["Puffy", "Jelly", "Judy"]
    scores = [91, 85, 79]
    plt.bar(names, scores)

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 15**

# %%
num = 15
"""
Write a code to save a plot as png with a file name “output.”
"""

def answer():
    plt.plot([1, 2, 3], [4, 5, 6])
    plt.savefig("output.png")

checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 16**

# %%
num = 16
"""
Fix the code.
"""

def answer():
    plt.plot([1, 2, 3], [4, 5, 6])
    plt.title("Line Graph")
    plt.show()
    
checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 17**

# %%
num = 17
"""
Fix the code
"""

def answer():
    plt.plot([1, 2, 3], [4, 5, 3])
    plt.show()


checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 18**

# %%
num = 18
"""
Fix the code
"""

def answer():
    fig = plt.figure()
    fig.suptitle("My Figure")
    plt.show()


checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 19**

# %%
num = 19
"""
Fix the Code
"""

def answer():
    plt.plot([1, 2, 3], [4, 5, 6])
    plt.xlabel("X-Axis")
    plt.show()



checker_ans(answer, num, score)
# Out:
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Question 20**

# %%
num = 20
"""
Fix the code
"""

def answer():
    plt.plot([1, 2, 3], [4, 5, 6])
    plt.xlabel("X Axis")
    plt.ylabel("Y Axis")
    plt.legend()
    plt.show()


checker_ans(answer, num, score)
# Out:
# /tmp/ipykernel_36720/3880686546.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 'Correct, proceed to the next num'

# %% [markdown]
# ### **Check Score**

# %%
print(check_score(score))
# Out:
# You Total Score is 20
